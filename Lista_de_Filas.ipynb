# %% [markdown]
# <a href="https://colab.research.google.com/github/jpengtelecom/Trabalho01-Teoria-de-Filas/blob/main/Lista_de_Filas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt

t = 0 # tempo inicial
lq = 0 #numero de elementos na fila
ls = 1 #numero de elementos no servidor
k1 = 0 #variavel auxiliar
k2 = 0 #variavel auxiliar
k = 0 #numero de partidas
lambda1=0.6 #taxa media de chegada
mu1=1 #taxa media de partida
chegadas = np.random.exponential(1/lambda1,100000) #vetor de chegadas

partidas = np.random.exponential(1/mu1,100000) #vetor de partidas
tc = [0] #tempo de chegadas
tp = [] #tempo de partidas
ts = [] #tempo no sistema

ta = t + chegadas[k1] #proxima chegada
td = t + partidas[k2] #proxima partida
t = np.minimum(ta, td) #proximo tempo de execucao

while (t < 5000): #tempo limite de simulacao

    if ta<td: #evento de chegada
        k1 = k1 + 1
        ta = [] #apaga o tempo de chegada atual
        if ls == 1: #servidor ocupado
            lq = lq + 1 #aumenta a fila
            ta = t + chegadas[k1] #gera nova chegada
            tc = np.append(tc, t) #aramazena tempo atual de chegada

        else: #servidor desocupado
            ls = 1 #ocupa o servidor
            k2 = k2 + 1
            td = t + partidas[k2] #gera nova partida
            ta = t + chegadas[k1] #gera nova chegada
            tc = np.append(tc, t) #aramazena tempo atual de chegada


    elif ta == td: #chegada e partida simultanea

        tc = np.append(tc, t) #armazena o tempo atual de chegada
        tp = np.append(tp, t) #armazena o tempo atual de partida

        k = k + 1 #incrementa a partida

        ts = np.append(ts,(tp[k-1] - tc[k-1])) #calcula o tempo no sistema

        ta = [] #apaga os valores atuais de chegada e partida
        td = []
        k1 = k1 + 1
        k2 = k2 + 1
        td = t + partidas[k2] #calcula a proxima partida
        ta = t + chegadas[k1] #calcula a proxima chegada



    else: #evento de partida
        td = [] #apaga o tempo de partida

        k = k + 1 #incrementa o numero de partidas

        if lq > 0:#existem pacotes na fila
            tp = np.append(tp, t) #armazeno o tempo da partida
            ts = np.append(ts, (tp[k - 1] - tc[k - 1])) #calculo o tempo no sistema
            lq = lq - 1 #diminuo a fila em 1
            k2 = k2 + 1
            td = t + partidas[k2]#calculo a proxima partida

        else: #nao ha pacotes na fila
            tp = np.append(tp, t)#armazeno o tempo da partida
            ts = np.append(ts, (tp[k - 1] - tc[k - 1])) #calculo o tempo no sistema

            td = np.infty #coloco um valor muito grande para a proxima partida
            ls = 0 #esvazio o servidor


    t = np.minimum(ta, td) #calculo o tempo minimo entre chegada e partida

tw=np.mean(ts)-1/mu1
eq=lambda1*np.mean(ts)
ew=lambda1*tw
rho=lambda1/mu1
print("fator de utilizacao rho")
print(rho)
print("tempo no sistema")
print(np.mean(ts))
print("tempo na fila")
print(tw)
print("numero medio de carros no sistema")
print(eq)
print("numero medio de carros na fila")
print(ew)
# Out:
# fator de utilizacao rho
# 0.6
# tempo no sistema
# 2.423479140555838
# tempo na fila
# 1.423479140555838
# numero medio de carros no sistema
# 1.4540874843335028
# numero medio de carros na fila
# 0.8540874843335028

# %% [markdown]
# # EXERCICIO 02

# %%
import numpy as np
import matplotlib.pyplot as plt
t = 0 #tempo inicial
lq = 0 #numero de elementos na fila
ls = 1 #numero de elementos no servidor
k1 = 0 #variavel auxiliar
k2 = 0 #variavel auxiliar
k = 0 #numero de partidas
lambda1=40 #taxa media de chegada
mu1=100 #taxa media de partida
chegadas = np.random.exponential(1/lambda1,1000000) #vetor de chegadas
#chegadas = 1/lambda1*np.ones(100000)
partidas = np.random.exponential(1/mu1,1000000) #vetor de partidas
tc = [0] #tempo de chegadas
tp = [] #tempo de partidas
ts = [] #tempo no sistema

ta = t + chegadas[k1] #proxima chegada
td = t + partidas[k2] #proxima partida
t = np.minimum(ta, td) #proximo tempo de execucao

while (t < 5000): #tempo limite de simulacao

    if ta<td: #evento de chegada
        k1 = k1 + 1
        ta = [] #apaga o tempo de chegada atual
        if ls == 1: #servidor ocupado
            lq = lq + 1 #aumenta a fila
            ta = t + chegadas[k1] #gera nova chegada
            tc = np.append(tc, t) #aramazena tempo atual de chegada

        else: #servidor desocupado
            ls = 1 #ocupa o servidor
            k2 = k2 + 1
            td = t + partidas[k2] #gera nova partida
            ta = t + chegadas[k1] #gera nova chegada
            tc = np.append(tc, t) #aramazena tempo atual de chegada


    elif ta == td: #chegada e partida simultanea

        tc = np.append(tc, t) #armazena o tempo atual de chegada
        tp = np.append(tp, t) #armazena o tempo atual de partida

        k = k + 1 #incrementa a partida

        ts = np.append(ts,(tp[k-1] - tc[k-1])) #calcula o tempo no sistema

        ta = [] #apaga os valores atuais de chegada e partida
        td = []
        k1 = k1 + 1
        k2 = k2 + 1
        td = t + partidas[k2] #calcula a proxima partida
        ta = t + chegadas[k1] #calcula a proxima chegada



    else: #evento de partida
        td = [] #apaga o tempo de partida

        k = k + 1 #incrementa o numero de partidas

        if lq > 0:#existem pacotes na fila
            tp = np.append(tp, t) #armazeno o tempo da partida
            ts = np.append(ts, (tp[k - 1] - tc[k - 1])) #calculo o tempo no sistema
            lq = lq - 1 #diminuo a fila em 1
            k2 = k2 + 1
            td = t + partidas[k2]#calculo a proxima partida

        else: #nao ha pacotes na fila
            tp = np.append(tp, t)#armazeno o tempo da partida
            ts = np.append(ts, (tp[k - 1] - tc[k - 1])) #calculo o tempo no sistema

            td = np.infty #coloco um valor muito grande para a proxima partida
            ls = 0 #esvazio o servidor


    t = np.minimum(ta, td) #calculo o tempo minimo entre chegada e partida

tw=np.mean(ts)-1/mu1
eq=lambda1*np.mean(ts)
ew=lambda1*tw
rho=lambda1/mu1
print("fator de utilizacao rho")
print(rho)
print("tempo no sistema")
print(np.mean(ts))
print("tempo na fila")
print(tw)
print("numero medio de pacotes no sistema")
print(eq)
print("numero medio de pacotes na fila")
print(ew)
# Out:
# fator de utilizacao rho
# 0.4
# tempo no sistema
# 0.016631784096195826
# tempo na fila
# 0.0066317840961958256
# numero medio de pacotes no sistema
# 0.665271363847833
# numero medio de pacotes na fila
# 0.265271363847833

# %% [markdown]
# Ex.3

# %%
import numpy as np
import matplotlib.pyplot as plt
t = 0 #tempo inicial
lq = 0 #numero de elementos na fila
ls = 1 #numero de elementos no servidor
k1 = 0 #variavel auxiliar
k2 = 0 #variavel auxiliar
k = 0 #numero de partidas
count = 1
block = 0
lambda1=200 #taxa media de chegada
mu1=250 #taxa media de partida
chegadas = np.random.exponential(1/lambda1,100000) #vetor de chegadas

partidas = np.random.exponential(1/mu1,100000) #vetor de partidas
tc = [0] #tempo de chegadas
tp = [] #tempo de partidas
ts = [] #tempo no sistema
N = 2
ta = t + chegadas[k1] #proxima chegada
td = t + partidas[k2] #proxima partida
t = np.minimum(ta, td) #proximo tempo de execucao

while (k < 10000): #tempo limite de simulacao

    if ta<td: #evento de chegada
        count=count+1
        k1 = k1 + 1
        ta = [] #apaga o tempo de chegada atual
        if ls == 1: #servidor ocupado
          if (lq+1)<N: #verifica se i sistema esta ocupado, nao estando
              lq = lq + 1 #aumenta a fila
              ta = t + chegadas[k1] #gera nova chegada
              tc = np.append(tc, t) #aramazena tempo atual de chegada
          else: #sistema ocupado
              ta = t + chegadas[k1]
              block=block+1
              #bloqueia o pacote

        else: #servidor desocupado
            ls = 1 #ocupa o servidor
            k2 = k2 + 1
            td = t + partidas[k2] #gera nova partida
            ta = t + chegadas[k1] #gera nova chegada
            tc = np.append(tc, t) #aramazena tempo atual de chegada


    elif ta == td: #chegada e partida simultanea

        tc = np.append(tc, t) #armazena o tempo atual de chegada
        tp = np.append(tp, t) #armazena o tempo atual de partida

        k = k + 1 #incrementa a partida

        ts = np.append(ts,(tp[k-1] - tc[k-1])) #calcula o tempo no sistema

        ta = [] #apaga os valores atuais de chegada e partida
        td = []
        k1 = k1 + 1
        k2 = k2 + 1
        td = t + partidas[k2] #calcula a proxima partida
        ta = t + chegadas[k1] #calcula a proxima chegada



    else: #evento de partida
        td = [] #apaga o tempo de partida

        k = k + 1 #incrementa o numero de partidas

        if lq > 0:#existem pacotes na fila
            tp = np.append(tp, t) #armazeno o tempo da partida
            ts = np.append(ts, (tp[k - 1] - tc[k - 1])) #calculo o tempo no sistema
            lq = lq - 1 #diminuo a fila em 1
            k2 = k2 + 1
            td = t + partidas[k2]#calculo a proxima partida

        else: #nao ha pacotes na fila
            tp = np.append(tp, t)#armazeno o tempo da partida
            ts = np.append(ts, (tp[k - 1] - tc[k - 1])) #calculo o tempo no sistema

            td = np.infty #coloco um valor muito grande para a proxima partida
            ls = 0 #esvazio o servidor


    t = np.minimum(ta, td) #calculo o tempo minimo entre chegada e partida

pb=block/count
print("probabilidade de bloqueio")
print(pb)
tw=np.mean(ts)-1/mu1
eq=lambda1*np.mean(ts)
ew=lambda1*tw
rho=lambda1/mu1
print("fator de utilizacao rho")
print(rho)
print("tempo no sistema")
print(np.mean(ts))
print("tempo na fila")
print(tw)
print("numero medio de pacotes no sistema")
print(eq)
print("numero medio de pacotes na fila")
print(ew)
# Out:
# probabilidade de bloqueio
# 0.2583252985240673
# fator de utilizacao rho
# 0.8
# tempo no sistema
# 0.005825043645480301
# tempo na fila
# 0.0018250436454803013
# numero medio de pacotes no sistema
# 1.1650087290960602
# numero medio de pacotes na fila
# 0.36500872909606025

# %%
import numpy as np
import matplotlib.pyplot as plt
t = 0 #tempo inicial
lq = 0 #numero de elementos na fila
ls = 1 #numero de elementos no servidor
k1 = 0 #variavel auxiliar
k2 = 0 #variavel auxiliar
k = 0 #numero de partidas
count = 1
block = 0
lambda1=200 #taxa media de chegada
mu1=250 #taxa media de partida
chegadas = np.random.exponential(1/lambda1,100000) #vetor de chegadas

partidas = np.random.exponential(1/mu1,100000) #vetor de partidas
tc = [0] #tempo de chegadas
tp = [] #tempo de partidas
ts = [] #tempo no sistema
N = 6
ta = t + chegadas[k1] #proxima chegada
td = t + partidas[k2] #proxima partida
t = np.minimum(ta, td) #proximo tempo de execucao

while (k < 10000): #tempo limite de simulacao

    if ta<td: #evento de chegada
        count=count+1
        k1 = k1 + 1
        ta = [] #apaga o tempo de chegada atual
        if ls == 1: #servidor ocupado
          if (lq+1)<N: #verifica se i sistema esta ocupado, nao estando
              lq = lq + 1 #aumenta a fila
              ta = t + chegadas[k1] #gera nova chegada
              tc = np.append(tc, t) #aramazena tempo atual de chegada
          else: #sistema ocupado
              ta = t + chegadas[k1]
              block=block+1
              #bloqueia o pacote

        else: #servidor desocupado
            ls = 1 #ocupa o servidor
            k2 = k2 + 1
            td = t + partidas[k2] #gera nova partida
            ta = t + chegadas[k1] #gera nova chegada
            tc = np.append(tc, t) #aramazena tempo atual de chegada


    elif ta == td: #chegada e partida simultanea

        tc = np.append(tc, t) #armazena o tempo atual de chegada
        tp = np.append(tp, t) #armazena o tempo atual de partida

        k = k + 1 #incrementa a partida

        ts = np.append(ts,(tp[k-1] - tc[k-1])) #calcula o tempo no sistema

        ta = [] #apaga os valores atuais de chegada e partida
        td = []
        k1 = k1 + 1
        k2 = k2 + 1
        td = t + partidas[k2] #calcula a proxima partida
        ta = t + chegadas[k1] #calcula a proxima chegada



    else: #evento de partida
        td = [] #apaga o tempo de partida

        k = k + 1 #incrementa o numero de partidas

        if lq > 0:#existem pacotes na fila
            tp = np.append(tp, t) #armazeno o tempo da partida
            ts = np.append(ts, (tp[k - 1] - tc[k - 1])) #calculo o tempo no sistema
            lq = lq - 1 #diminuo a fila em 1
            k2 = k2 + 1
            td = t + partidas[k2]#calculo a proxima partida

        else: #nao ha pacotes na fila
            tp = np.append(tp, t)#armazeno o tempo da partida
            ts = np.append(ts, (tp[k - 1] - tc[k - 1])) #calculo o tempo no sistema

            td = np.infty #coloco um valor muito grande para a proxima partida
            ls = 0 #esvazio o servidor


    t = np.minimum(ta, td) #calculo o tempo minimo entre chegada e partida

pb=block/count
print("probabilidade de bloqueio")
print(pb)
tw=np.mean(ts)-1/mu1
eq=lambda1*np.mean(ts)
ew=lambda1*tw
rho=lambda1/mu1
print("fator de utilizacao rho")
print(rho)
print("tempo no sistema")
print(np.mean(ts))
print("tempo na fila")
print(tw)
print("numero medio de pacotes no sistema")
print(eq)
print("numero medio de pacotes na fila")
print(ew)
# Out:
# probabilidade de bloqueio
# 0.07086467911210179
# fator de utilizacao rho
# 0.8
# tempo no sistema
# 0.011395092205140494
# tempo na fila
# 0.007395092205140494
# numero medio de pacotes no sistema
# 2.2790184410280987
# numero medio de pacotes na fila
# 1.4790184410280989

# %%
import numpy as np
import matplotlib.pyplot as plt
t = 0 #tempo inicial
lq = 0 #numero de elementos na fila
ls = 1 #numero de elementos no servidor
k1 = 0 #variavel auxiliar
k2 = 0 #variavel auxiliar
k = 0 #numero de partidas
count = 1
block = 0
lambda1=200 #taxa media de chegada
mu1=250 #taxa media de partida
chegadas = np.random.exponential(1/lambda1,100000) #vetor de chegadas

partidas = np.random.exponential(1/mu1,100000) #vetor de partidas
tc = [0] #tempo de chegadas
tp = [] #tempo de partidas
ts = [] #tempo no sistema
N = 11
ta = t + chegadas[k1] #proxima chegada
td = t + partidas[k2] #proxima partida
t = np.minimum(ta, td) #proximo tempo de execucao

while (k < 10000): #tempo limite de simulacao

    if ta<td: #evento de chegada
        count=count+1
        k1 = k1 + 1
        ta = [] #apaga o tempo de chegada atual
        if ls == 1: #servidor ocupado
          if (lq+1)<N: #verifica se i sistema esta ocupado, nao estando
              lq = lq + 1 #aumenta a fila
              ta = t + chegadas[k1] #gera nova chegada
              tc = np.append(tc, t) #aramazena tempo atual de chegada
          else: #sistema ocupado
              ta = t + chegadas[k1]
              block=block+1
              #bloqueia o pacote

        else: #servidor desocupado
            ls = 1 #ocupa o servidor
            k2 = k2 + 1
            td = t + partidas[k2] #gera nova partida
            ta = t + chegadas[k1] #gera nova chegada
            tc = np.append(tc, t) #aramazena tempo atual de chegada


    elif ta == td: #chegada e partida simultanea

        tc = np.append(tc, t) #armazena o tempo atual de chegada
        tp = np.append(tp, t) #armazena o tempo atual de partida

        k = k + 1 #incrementa a partida

        ts = np.append(ts,(tp[k-1] - tc[k-1])) #calcula o tempo no sistema

        ta = [] #apaga os valores atuais de chegada e partida
        td = []
        k1 = k1 + 1
        k2 = k2 + 1
        td = t + partidas[k2] #calcula a proxima partida
        ta = t + chegadas[k1] #calcula a proxima chegada



    else: #evento de partida
        td = [] #apaga o tempo de partida

        k = k + 1 #incrementa o numero de partidas

        if lq > 0:#existem pacotes na fila
            tp = np.append(tp, t) #armazeno o tempo da partida
            ts = np.append(ts, (tp[k - 1] - tc[k - 1])) #calculo o tempo no sistema
            lq = lq - 1 #diminuo a fila em 1
            k2 = k2 + 1
            td = t + partidas[k2]#calculo a proxima partida

        else: #nao ha pacotes na fila
            tp = np.append(tp, t)#armazeno o tempo da partida
            ts = np.append(ts, (tp[k - 1] - tc[k - 1])) #calculo o tempo no sistema

            td = np.infty #coloco um valor muito grande para a proxima partida
            ls = 0 #esvazio o servidor


    t = np.minimum(ta, td) #calculo o tempo minimo entre chegada e partida

pb=block/count
print("probabilidade de bloqueio")
print(pb)
tw=np.mean(ts)-1/mu1
eq=lambda1*np.mean(ts)
ew=lambda1*tw
rho=lambda1/mu1
print("fator de utilizacao rho")
print(rho)
print("tempo no sistema")
print(np.mean(ts))
print("tempo na fila")
print(tw)
print("numero medio de pacotes no sistema")
print(eq)
print("numero medio de pacotes na fila")
print(ew)
# Out:
# probabilidade de bloqueio
# 0.018549416036902543
# fator de utilizacao rho
# 0.8
# tempo no sistema
# 0.01587597400797553
# tempo na fila
# 0.011875974007975531
# numero medio de pacotes no sistema
# 3.175194801595106
# numero medio de pacotes na fila
# 2.3751948015951063

# %%
import numpy as np
import matplotlib.pyplot as plt

t = 0 # tempo inicial
lq = 0 #numero de elementos na fila
ls = 1 #numero de elementos no servidor
k1 = 0 #variavel auxiliar
k2 = 0 #variavel auxiliar
k = 0 #numero de partidas
count = 1
block = 0
lambda1=200 #taxa media de chegada
mu1=250 #taxa media de partida
chegadas = np.random.exponential(1/lambda1,100000) #vetor de chegadas

partidas = np.random.exponential(1/mu1,100000) #vetor de partidas
tc = [0] #tempo de chegadas
tp = [] #tempo de partidas
ts = [] #tempo no sistema
N = 16
ta = t + chegadas[k1] #proxima chegada
td = t + partidas[k2] #proxima partida
t = np.minimum(ta, td) #proximo tempo de execucao

while (k < 10000): #tempo limite de simulacao

    if ta<td: #evento de chegada
        count=count+1
        k1 = k1 + 1
        ta = [] #apaga o tempo de chegada atual
        if ls == 1: #servidor ocupado
          if (lq+1)<N: #verifica se i sistema esta ocupado, nao estando
              lq = lq + 1 #aumenta a fila
              ta = t + chegadas[k1] #gera nova chegada
              tc = np.append(tc, t) #aramazena tempo atual de chegada
          else: #sistema ocupado
              ta = t + chegadas[k1]
              block=block+1
              #bloqueia o pacote

        else: #servidor desocupado
            ls = 1 #ocupa o servidor
            k2 = k2 + 1
            td = t + partidas[k2] #gera nova partida
            ta = t + chegadas[k1] #gera nova chegada
            tc = np.append(tc, t) #aramazena tempo atual de chegada


    elif ta == td: #chegada e partida simultanea

        tc = np.append(tc, t) #armazena o tempo atual de chegada
        tp = np.append(tp, t) #armazena o tempo atual de partida

        k = k + 1 #incrementa a partida

        ts = np.append(ts,(tp[k-1] - tc[k-1])) #calcula o tempo no sistema

        ta = [] #apaga os valores atuais de chegada e partida
        td = []
        k1 = k1 + 1
        k2 = k2 + 1
        td = t + partidas[k2] #calcula a proxima partida
        ta = t + chegadas[k1] #calcula a proxima chegada



    else: #evento de partida
        td = [] #apaga o tempo de partida

        k = k + 1 #incrementa o numero de partidas

        if lq > 0:#existem pacotes na fila
            tp = np.append(tp, t) #armazeno o tempo da partida
            ts = np.append(ts, (tp[k - 1] - tc[k - 1])) #calculo o tempo no sistema
            lq = lq - 1 #diminuo a fila em 1
            k2 = k2 + 1
            td = t + partidas[k2]#calculo a proxima partida

        else: #nao ha pacotes na fila
            tp = np.append(tp, t)#armazeno o tempo da partida
            ts = np.append(ts, (tp[k - 1] - tc[k - 1])) #calculo o tempo no sistema

            td = np.infty #coloco um valor muito grande para a proxima partida
            ls = 0 #esvazio o servidor


    t = np.minimum(ta, td) #calculo o tempo minimo entre chegada e partida

pb=block/count
print("probabilidade de bloqueio")
print(pb)
tw=np.mean(ts)-1/mu1
eq=lambda1*np.mean(ts)
ew=lambda1*tw
rho=lambda1/mu1
print("fator de utilizacao rho")
print(rho)
print("tempo no sistema")
print(np.mean(ts))
print("tempo na fila")
print(tw)
print("numero medio de pacotes no sistema")
print(eq)
print("numero medio de pacotes na fila")
print(ew)
# Out:
# probabilidade de bloqueio
# 0.005468827682211395
# fator de utilizacao rho
# 0.8
# tempo no sistema
# 0.017825433283604163
# tempo na fila
# 0.013825433283604163
# numero medio de pacotes no sistema
# 3.5650866567208324
# numero medio de pacotes na fila
# 2.7650866567208325

# %% [markdown]
# Ex.4

# %%
import numpy as np
import matplotlib.pyplot as plt
t = 0 #tempo inicial
lq = 0 #numero de elementos na fila
ls = 1 #numero de elementos no servidor
k1 = 0 #variavel auxiliar
k2 = 0 #variavel auxiliar
k = 0 #numero de partidas
lambda1=1 #taxa media de chegada
mu1=5 #taxa media de partida
chegadas = np.random.exponential(1/lambda1,100000) #vetor de chegadas
#partidas = np.random.exponential(1/mu1,100000) #vetor de partidas
partidas = 1/mu1*np.ones(100000)
tc = [0] #tempo de chegadas
tp = [] #tempo de partidas
ts = [] #tempo no sistema

ta = t + chegadas[k1] #proxima chegada
td = t + partidas[k2] #proxima partida
t = np.minimum(ta, td) #proximo tempo de execucao

while (t < 5000): #tempo limite de simulacao

    if ta<td: #evento de chegada
        k1 = k1 + 1
        ta = [] #apaga o tempo de chegada atual
        if ls == 1: #servidor ocupado
            lq = lq + 1 #aumenta a fila
            ta = t + chegadas[k1] #gera nova chegada
            tc = np.append(tc, t) #aramazena tempo atual de chegada

        else: #servidor desocupado
            ls = 1 #ocupa o servidor
            k2 = k2 + 1
            td = t + partidas[k2] #gera nova partida
            ta = t + chegadas[k1] #gera nova chegada
            tc = np.append(tc, t) #aramazena tempo atual de chegada


    elif ta == td: #chegada e partida simultanea

        tc = np.append(tc, t) #armazena o tempo atual de chegada
        tp = np.append(tp, t) #armazena o tempo atual de partida

        k = k + 1 #incrementa a partida

        ts = np.append(ts,(tp[k-1] - tc[k-1])) #calcula o tempo no sistema

        ta = [] #apaga os valores atuais de chegada e partida
        td = []
        k1 = k1 + 1
        k2 = k2 + 1
        td = t + partidas[k2] #calcula a proxima partida
        ta = t + chegadas[k1] #calcula a proxima chegada



    else: #evento de partida
        td = [] #apaga o tempo de partida

        k = k + 1 #incrementa o numero de partidas

        if lq > 0:#existem pacotes na fila
            tp = np.append(tp, t) #armazeno o tempo da partida
            ts = np.append(ts, (tp[k - 1] - tc[k - 1])) #calculo o tempo no sistema
            lq = lq - 1 #diminuo a fila em 1
            k2 = k2 + 1
            td = t + partidas[k2]#calculo a proxima partida

        else: #nao ha pacotes na fila
            tp = np.append(tp, t)#armazeno o tempo da partida
            ts = np.append(ts, (tp[k - 1] - tc[k - 1])) #calculo o tempo no sistema

            td = np.infty #coloco um valor muito grande para a proxima partida
            ls = 0 #esvazio o servidor


    t = np.minimum(ta, td) #calculo o tempo minimo entre chegada e partida

tw=np.mean(ts)-1/mu1
eq=lambda1*np.mean(ts)
ew=lambda1*tw
rho=lambda1/mu1
print("fator de utilizacao rho")
print(rho)
print("tempo no sistema")
print(np.mean(ts))
print("tempo na fila")
print(tw)
print("numero medio de pacotes no sistema")
print(eq)
print("numero medio de pacotes na fila")
print(ew)
# Out:
# fator de utilizacao rho
# 0.2
# tempo no sistema
# 0.22709683088140925
# tempo na fila
# 0.02709683088140924
# numero medio de pacotes no sistema
# 0.22709683088140925
# numero medio de pacotes na fila
# 0.02709683088140924

# %%
import numpy as np
import matplotlib.pyplot as plt
t = 0 #tempo inicial
lq = 0 #numero de elementos na fila
ls = 1 #numero de elementos no servidor
k1 = 0 #variavel auxiliar
k2 = 0 #variavel auxiliar
k = 0 #numero de partidas
lambda1=1 #taxa media de chegada
mu1=5 #taxa media de partida
chegadas = np.random.exponential(1/lambda1,100000) #vetor de chegadas

partidas = np.random.exponential(1/mu1,100000) #vetor de partidas
tc = [0] #tempo de chegadas
tp = [] #tempo de partidas
ts = [] #tempo no sistema

ta = t + chegadas[k1] #proxima chegada
td = t + partidas[k2] #proxima partida
t = np.minimum(ta, td) #proximo tempo de execucao

while (t < 5000): #tempo limite de simulacao

    if ta<td: #evento de chegada
        k1 = k1 + 1
        ta = [] #apaga o tempo de chegada atual
        if ls == 1: #servidor ocupado
            lq = lq + 1 #aumenta a fila
            ta = t + chegadas[k1] #gera nova chegada
            tc = np.append(tc, t) #aramazena tempo atual de chegada

        else: #servidor desocupado
            ls = 1 #ocupa o servidor
            k2 = k2 + 1
            td = t + partidas[k2] #gera nova partida
            ta = t + chegadas[k1] #gera nova chegada
            tc = np.append(tc, t) #aramazena tempo atual de chegada


    elif ta == td: #chegada e partida simultanea

        tc = np.append(tc, t) #armazena o tempo atual de chegada
        tp = np.append(tp, t) #armazena o tempo atual de partida

        k = k + 1 #incrementa a partida

        ts = np.append(ts,(tp[k-1] - tc[k-1])) #calcula o tempo no sistema

        ta = [] #apaga os valores atuais de chegada e partida
        td = []
        k1 = k1 + 1
        k2 = k2 + 1
        td = t + partidas[k2] #calcula a proxima partida
        ta = t + chegadas[k1] #calcula a proxima chegada



    else: #evento de partida
        td = [] #apaga o tempo de partida

        k = k + 1 #incrementa o numero de partidas

        if lq > 0:#existem pacotes na fila
            tp = np.append(tp, t) #armazeno o tempo da partida
            ts = np.append(ts, (tp[k - 1] - tc[k - 1])) #calculo o tempo no sistema
            lq = lq - 1 #diminuo a fila em 1
            k2 = k2 + 1
            td = t + partidas[k2]#calculo a proxima partida

        else: #nao ha pacotes na fila
            tp = np.append(tp, t)#armazeno o tempo da partida
            ts = np.append(ts, (tp[k - 1] - tc[k - 1])) #calculo o tempo no sistema

            td = np.infty #coloco um valor muito grande para a proxima partida
            ls = 0 #esvazio o servidor


    t = np.minimum(ta, td) #calculo o tempo minimo entre chegada e partida

tw=np.mean(ts)-1/mu1
eq=lambda1*np.mean(ts)
ew=lambda1*tw
rho=lambda1/mu1
print("fator de utilizacao rho")
print(rho)
print("tempo no sistema")
print(np.mean(ts))
print("tempo na fila")
print(tw)
print("numero medio de pacotes no sistema")
print(eq)
print("numero medio de pacotes na fila")
print(ew)
# Out:
# fator de utilizacao rho
# 0.2
# tempo no sistema
# 0.2546992205904732
# tempo na fila
# 0.05469922059047316
# numero medio de pacotes no sistema
# 0.2546992205904732
# numero medio de pacotes na fila
# 0.05469922059047316
